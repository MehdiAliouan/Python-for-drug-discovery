# %% [markdown]
# ### PART 1 — Data Collection & Preprocessing
#
# #### We will:
#
# #### - Query ChEMBL for COX-2 (PTGS2)
#
# #### - Retrieve bioactivity data (IC50)
#
# #### - Clean and standardize
#
# #### - Convert IC50 → pIC50
#
# #### - Save clean dataset

# %%
# importing the libraries
import os
import pandas as pd
import numpy as np
from chembl_webresource_client.new_client import new_client

# %%
# Searching for COX-2 Target in ChEMBL

target = new_client.target
target_query = target.search('cyclooxygenase-2')
targets = pd.DataFrame(target_query)

targets.head()
# Out:
#   cross_references                organism         pref_name  score  \
# 0               []  Canis lupus familiaris  Cyclooxygenase-2   20.0
# 1               []             Felis catus  Cyclooxygenase 2   20.0
# 2               []          Equus caballus  Cyclooxygenase-1   19.0
# 3               []            Homo sapiens    Cyclooxygenase   17.0
# 4               []       Rattus norvegicus    Cyclooxygenase   17.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL4033
# 1               False    CHEMBL5303558
# 2               False    CHEMBL5303565
# 3               False    CHEMBL2094253
# 4               False    CHEMBL2095157
#
#                                    target_components     target_type   tax_id
# 0  [{'accession': 'Q8SPQ9', 'component_descriptio...  SINGLE PROTEIN   9615.0
# 1  [{'accession': 'A8QIU4', 'component_descriptio...  SINGLE PROTEIN   9685.0
# 2  [{'accession': 'Q9N2C8', 'component_descriptio...  SINGLE PROTEIN   9796.0
# ...

# %%
# filtring for humain

targets[targets['organism'] == 'Homo sapiens']
# Out:
#      cross_references      organism  \
# 3                  []  Homo sapiens
# 6                  []  Homo sapiens
# 16                 []  Homo sapiens
# 18                 []  Homo sapiens
# 22                 []  Homo sapiens
# ...               ...           ...
# 3356               []  Homo sapiens
# 3358               []  Homo sapiens
# 3359               []  Homo sapiens
# 3368               []  Homo sapiens
# 3372               []  Homo sapiens
#
#                                          pref_name  score  species_group_flag  \
# 3                                   Cyclooxygenase   17.0               False
# 6                           Thromboxane-A synthase   15.0               False
# 16                                     COX-1/COX-2   14.0               False
# 18                    Prostaglandin G/H synthase 2   13.0               False
# 22                    Prostaglandin G/H synthase 1    9.0               False
# ...

# %%
target_id = "CHEMBL230"

# %%
# Retrive Bioactivity Data(IC50 Only)

activity = new_client.activity

res = activity.filter(
    target_chembl_id=target_id
).filter(
    standard_type="IC50"
)

df = pd.DataFrame(res)
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        34205                  []
# 1        None             None        34209                  []
# 2        None             None        35476                  []
# 3        None             None        36218                  []
# 4        None             None        36708                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL762912  In vitro inhibitory activity against human pro...
# 1    CHEMBL762912  In vitro inhibitory activity against human pro...
# 2    CHEMBL762912  In vitro inhibitory activity against human pro...
# 3    CHEMBL769655  Tested in vitro for inhibition against Prostag...
# 4    CHEMBL762912  In vitro inhibitory activity against human pro...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# ...

# %%
# Keeping the relevant columns 

df = df[['molecule_chembl_id',
         'canonical_smiles',
         'standard_value',
         'standard_units']]

df.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL297008           Cc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccccc1
# 1       CHEMBL289813   Cc1c(C=O)cc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1
# 2        CHEMBL43736  Cc1c(COc2cccc(Cl)c2)cc(-c2ccc(S(C)(=O)=O)cc2)n...
# 3       CHEMBL140167     Fc1ccc(-c2[nH]c(-c3ccc(F)cc3)c3c2C2CCC3CC2)cc1
# 4        CHEMBL44194       CCc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1
#
#   standard_value standard_units
# 0           60.0             nM
# 1         3230.0             nM
# 2           80.0             nM
# 3           0.12             nM
# 4       100000.0             nM

# %% [markdown]
# ### Data Cleaning

# %%
# Removing missing values

df = df.dropna()

# %%
# Keeping only the nM values

df = df[df['standard_units'] == 'nM']

# %%
# Convert IC50 to numeric

df['standard_value'] = pd.to_numeric(df['standard_value'])

# %%
# Removing duplicates

df = df.drop_duplicates(subset='molecule_chembl_id')

# %%
# Converting IC50 → pIC50

df['pIC50'] = -np.log10(df['standard_value'] * 1e-9)

df[['standard_value', 'pIC50']].head()
# Out:
# C:\Users\ElMehdi\anaconda3\envs\cox2_ml\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    standard_value     pIC50
# 0           60.00  7.221849
# 1         3230.00  5.490797
# 2           80.00  7.096910
# 3            0.12  9.920819
# 4       100000.00  4.000000

# %%
### Quality check

# %%
# Dataset size

print("Number of compounds:", df.shape[0])
# Out:
# Number of compounds: 5377

# %%
# Saving the clean dataset

df.to_csv("cox2_clean.csv", index=False)

print("Fichier sauvegardé au même endroit que ce notebook.")
# Out:
# Fichier sauvegardé au même endroit que ce notebook.
